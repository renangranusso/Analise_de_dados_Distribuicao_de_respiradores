# %%
import pandas as pd
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

filename = 'distribuicao_respiradores.csv' #arquivo na pasta usuários
df = pd.read_csv(filename, sep=";") #sep == separador para colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1730 entries, 0 to 1729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATA              1730 non-null   object
#  1   FORNECEDOR        1730 non-null   object
#  2   DESTINO           1730 non-null   object
#  3   ESTADO/MUNICIPIO  1730 non-null   object
#  4   TIPO              1730 non-null   object
#  5   QUANTIDADE        1730 non-null   int64
#  6   VALOR             1730 non-null   object
#  7   DESTINATARIO      1730 non-null   object
#  8   UF                1730 non-null   object
#  9   DATA DE ENTREGA   1730 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 74.4+ KB

# %%
Graf = df.groupby('FORNECEDOR').size().sort_values().tail(10).plot(title='Número total de Respiradores distribuidos por Fornecedores', kind='barh', figsize=(10,5))

# %%
graf = df.groupby('DESTINO').size().sort_values()

n = graf.count()

graf.tail(int(n)).plot(title="Respiradores recebidos por Destino", kind='barh', figsize=(10,10))

# %%
for index, row in df.iterrows():
    if row['DESTINO'] != 'SÃO PAULO':
        df.drop(index, inplace=True)  #Removendo tudo o que não é Sao Paulo
        
graf = df.groupby('FORNECEDOR').size().sort_values()

n = graf.count()
        
graf.tail(int(n)).plot(title="Numero de respiradores entregues por cada fornecedor em São Paulo", kind='barh', figsize=(10,5))
